# %%
#importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading csv file
data = pd.read_csv("heart.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#Fetching number of rows and columns
data.shape
# Out:
# (303, 14)

# %%
#Checking null values
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#Calculating statistics
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#Getting top 5 entries
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
##
1 Binary
2 sex(0 = Female,1 = male)
3 fbs:Fasting Blood sugar > 120 mg/d1
4 exang:Exercise induced angina (0=no; 1=yes)
5 Categorical
6 cp:Chest Pain Type(0 = Asymptomatic angina; 1 = Atypical angina; 2 = Non-angina; 3 = Typical angina)
7 restecg: Resting ECG (0 = Left Ventricular hypertrophy; 1 = Normal; 2 = ST-T Wave abnormality)
8 slope: Slope of the peak exercise ST Segment (0 = Downsloping ; 1 = Upsloping ; 2 = Flat)
9 thal:Thalium stress test result ( 0 = NA; 1 = Fixed defect; 2 = Normal; 3 = Reversible defect)
10 Ordinal
11 ca: number of major vessels (0-3) colored by flourosopy
12 Numeric
13 age
14 oldpeak:ST Depression induced by exercise relative to rest
15 trestbps: Resting blood pressure
16 chol: Serum cholestrol in mg/dl
17 thalach: Maximum heart rate achieved during thalium stress test
18 Target
19 target: (1 = heart disease; 0 = no heart disease)
# Out:
#   Cell In[8], line 2
#     1 Binary
#       ^
# SyntaxError: invalid syntax

# %%
data.shape[0]  #rows
# Out:
# 303

# %%
data.shape[1]   #columns
# Out:
# 14

# %%
data.info()    #data types included
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.rename(columns={'sex':'gender'},inplace=True)
data.head()
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63       1   3       145   233    1        0      150      0      2.3
# 1   37       1   2       130   250    0        1      187      0      3.5
# 2   41       0   1       130   204    0        0      172      0      1.4
# 3   56       1   1       120   236    0        1      178      0      0.8
# 4   57       0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
# Changing gender values to categories
data.loc[data['gender'] == 0, 'gender'] = 'female'
data.loc[data['gender'] == 1, 'gender'] = 'male'

# Check the updated DataFrame
data.head()
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 1   37    male   2       130   250    0        1      187      0      3.5
# 2   41  female   1       130   204    0        0      172      0      1.4
# 3   56    male   1       120   236    0        1      178      0      0.8
# 4   57  female   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %% [markdown]
#  Categorical: chest_pain_type,Sex,fasting_blood_sugar,rest_ecg,exercise_induced_angina,st_slope,thalassemia
#  Numerical Features: Age (Continuous),resting_blood_pressure,cholesterol,max_heart_rate_achieved,st_depression,num_major_vessels,target

# %%
#MORE OF THE FEMALES ARE HAVING HEART DISEASE
sns.barplot(data=data, x='gender', y='target')

# Add title
plt.title('Heart Disease Distribution by Gender')

# Calculate and print the percentage of females with heart diseases
female_percentage = data['target'][data['gender'] == 'female'].value_counts(normalize=True).get(1, 0) * 100
print('Percentage of females with Heart Diseases:', female_percentage)

# Calculate and print the percentage of males with heart diseases
male_percentage = data['target'][data['gender'] == 'male'].value_counts(normalize=True).get(1, 0) * 100
print('Percentage of males with Heart Diseases:', male_percentage)
# Out:
# Percentage of females with Heart Diseases: 0
# Percentage of males with Heart Diseases: 0

# %%
data[['gender','target']].groupby(['gender']).mean()
# Out:
#           target
# gender
# female  0.750000
# male    0.449275

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
data[['gender','target']].groupby(['gender']).mean().plot.bar(ax=ax[0])
ax[0].set_title("Target vs Gender")
sns.countplot(x='gender',hue= 'target',data=data,ax = ax[1])
ax[1].set_title("GENDERWISE HEALTHY vs HEART DISEASE")
##According to the graph most of the men are healthy and few have heart disease which is reverse in female's case
# Out:
# Text(0.5, 1.0, 'GENDERWISE HEALTHY vs HEART DISEASE')

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
data['cp'].value_counts().plot.bar(ax=ax[0])
sns.countplot(x='cp',hue='target',data=data,ax=ax[1])

## Mostly people who have 2nd type of chest pain i.e. Non-Angina are likely to have a heart disease ##
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
sns.countplot(x='cp',hue='gender',data=data).set_title("GENDERWISE CHEST PAIN")
# Out:
# Text(0.5, 1.0, 'GENDERWISE CHEST PAIN')

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x='fbs',y='age',hue='target',data=data,split=True,ax=ax[0]).set_title("TARGET-WISE FASTING BLOOD SUGAR")
sns.violinplot(x='fbs',y='age',hue='gender',data=data,split=True,ax=ax[1]).set_title("TARGET-WISE FASTING BLOOD SUGAR")
# Out:
# Text(0.5, 1.0, 'TARGET-WISE FASTING BLOOD SUGAR')

# %%
sns.stripplot(x='gender',y='chol',hue='age',data=data,jitter=True,edgecolor='green')
# Out:
# <Axes: xlabel='gender', ylabel='chol'>

# %%
# Create a crosstab for 'target' and 'gender'
tab = pd.crosstab(data['target'], data['gender'])
print(tab)

# Normalize the crosstab table row-wise to get percentages
dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# Add labels to the plot
plt.xlabel('Target')
plt.ylabel('Percentage')

# Add a title to the plot
plt.title('Gender Distribution by Target Category')

#Show the graph
plt.show()
# Out:
# gender  female  male
# target
# 0           24   114
# 1           72    93

# %%
# Scatter plot between 'age' and 'oldpeak'
plt.scatter(data['age'], data['oldpeak'], color='b', alpha=0.6)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Oldpeak')
plt.title('Scatter Plot of Age vs. Oldpeak')

# Show the plot
plt.show()

# %%
# Convert gender to numerical values
data['gender'] = data['gender'].replace({'male': 1, 'female': 0})

# Calculate the correlation matrix again
corr_matrix = data.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap with Categorical Variables Encoded', fontsize=16)
plt.show()
# Out:
# C:\Users\devansh\AppData\Local\Temp\ipykernel_1116\693348031.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['gender'] = data['gender'].replace({'male': 1, 'female': 0})
